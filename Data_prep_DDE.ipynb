# %% [markdown]
# <a href="https://colab.research.google.com/github/manhanton/test_15June/blob/main/Data_prep_DDE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import datetime as dt
import os
import datetime as dt

# %%
# #please don't use `list` as a variable name.
# file_list = ['.csv']

# def yield_dfs(file_list):
#     """generator function to yield dataframes."""
#     for file_name in file_list:
#         df = pd.read_csv(file_name)
#         # you may be able to reduce the memory requirements by doing some pre-processing of the dataframe here. e.g. convert strings to booleans so save memore.
#         yield df

# df = pd.concat(yield_dfs(file_list))

# %%
import pandas as pd
path = "/content/drive/MyDrive/rawdata.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                                             Run Name  Run Start Time  \
# 0  \\TW7K20190008\c\Inficon\data\Chamber 2\2020-0...  3/19/2020 1:02
# 1  \\TW7K20190008\c\Inficon\data\Chamber 2\2020-0...  3/19/2020 1:02
# 2  \\TW7K20190008\c\Inficon\data\Chamber 2\2020-0...  3/19/2020 1:02
# 3  \\TW7K20190008\c\Inficon\data\Chamber 2\2020-0...  3/19/2020 1:02
# 4  \\TW7K20190008\c\Inficon\data\Chamber 2\2020-0...  3/19/2020 1:02
#
#                Tool Group Tool ID               Tool Description Tool Area  \
# 0  ESEC 2100sD Die Bonder  ES-177  ESEC 2100sD Die Bonder ES1201     C5 1F
# 1  ESEC 2100sD Die Bonder  ES-177  ESEC 2100sD Die Bonder ES1201     C5 1F
# 2  ESEC 2100sD Die Bonder  ES-177  ESEC 2100sD Die Bonder ES1201     C5 1F
# 3  ESEC 2100sD Die Bonder  ES-177  ESEC 2100sD Die Bonder ES1201     C5 1F
# 4  ESEC 2100sD Die Bonder  ES-177  ESEC 2100sD Die Bonder ES1201     C5 1F
#
#   Chamber ID Chamber Description  Chamber Number Sensor Kind  ...  \
# 0  Chamber 2     Glue Dispensing               2         TDS  ...
# 1  Chamber 2     Glue Dispensing               2         TDS  ...
# 2  Chamber 2     Glue Dispensing               2         TDS  ...
# 3  Chamber 2     Glue Dispensing               2         TDS  ...
# 4  Chamber 2     Glue Dispensing               2         TDS  ...
#
#   TDS: Trigger: CEID15328; CE_15328_StripRemovedClamp2  \
# 0                                          23094.497
# 1                                          23094.606
# 2                                          23094.716
# 3                                          23094.825
# 4                                          23094.934
#
#   TDS: Trigger: CEID15329; CE_15329_StripLeftClamp2  \
# 0                                           501.559
# 1                                           501.668
# 2                                           501.778
# 3                                           501.887
# 4                                           501.996
#
#   TDS: Trigger: CEID15330; CE_15330_StripArrivedClamp3  \
# 0                                            501.559
# 1                                            501.668
# 2                                            501.778
# 3                                            501.887
# 4                                            501.996
#
#   TDS: Trigger: CEID15331; CE_15331_StripInsertedClamp3  \
# 0                                          61328.763
# 1                                          61328.872
# 2                                          61328.982
# 3                                          61329.091
# 4                                          61329.200
#
#   TDS: Trigger: CEID15338; CE_15338_StripRemovedClamp3  \
# 0                                          61328.763
# 1                                          61328.872
# 2                                          61328.982
# 3                                          61329.091
# 4                                          61329.200
#
#   TDS: Trigger: CEID15339; CE_15339_StripLeftClamp3  \
# 0                                           296.714
# 1                                           296.823
# 2                                           296.933
# 3                                           297.042
# 4                                           297.151
#
#   TDS: Trigger: CEID15651; CE_15651_DispenseProcessDone  \
# 0                                           9994.017
# 1                                           9994.126
# 2                                           9994.236
# 3                                           9994.345
# 4                                           9994.454
#
#   TDS: Trigger: CEID15652; CE_15652_BondProcessDone  \
# 0                                          9983.362
# 1                                          9983.471
# 2                                          9983.581
# 3                                          9983.690
# 4                                          9983.799
#
#   TDS: Trigger: CEID15653; CE_15653_PickProcessDone  \
# 0                                          1421.871
# 1                                          1421.980
# 2                                          1422.090
# 3                                          1422.199
# 4                                          1422.308
#
#   TDS: Trigger: CEID3211; CE_3211_EnterExecProcessState
# 0                                          11275.612
# 1                                          11275.721
# 2                                          11275.831
# 3                                          11275.940
# 4                                          11276.049
#
# [5 rows x 59 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115927 entries, 0 to 115926
# Data columns (total 59 columns):
#  #   Column                                                             Non-Null Count   Dtype
# ---  ------                                                             --------------   -----
#  0   Run Name                                                           115927 non-null  object
#  1   Run Start Time                                                     115927 non-null  object
#  2   Tool Group                                                         115927 non-null  object
#  3   Tool ID                                                            115927 non-null  object
#  4   Tool Description                                                   115927 non-null  object
#  5   Tool Area                                                          115927 non-null  object
#  6   Chamber ID                                                         115927 non-null  object
#  7   Chamber Description                                                115927 non-null  object
#  8   Chamber Number                                                     115927 non-null  int64
#  9   Sensor Kind                                                        115927 non-null  object
#  10  Lot ID                                                             115927 non-null  object
#  11  Cassette ID                                                        115927 non-null  object
#  12  Slot ID                                                            115927 non-null  object
#  13  Substrate ID                                                       115927 non-null  object
#  14  Part ID                                                            115927 non-null  object
#  15  Layer ID                                                           115927 non-null  object
#  16  Technology ID                                                      115927 non-null  object
#  17  Operator ID                                                        115927 non-null  object
#  18  Sequence ID                                                        115927 non-null  object
#  19  Recipe ID                                                          115927 non-null  object
#  20  Blade Z1 ID                                                        115927 non-null  object
#  21  Blade Z2 ID                                                        115927 non-null  object
#  22  Port ID                                                            115927 non-null  object
#  23  Chuck ID                                                           115927 non-null  object
#  24  FullProductDescription ID                                          115927 non-null  object
#  25  Dispense Strip ID                                                  115927 non-null  object
#  26  Bond Strip ID                                                      115927 non-null  object
#  27  Extra 6 ID                                                         115927 non-null  object
#  28  Extra 7 ID                                                         115927 non-null  object
#  29  Extra 8 ID                                                         115927 non-null  object
#  30  Step Number                                                        115927 non-null  int64
#  31  Time                                                               115927 non-null  object
#  32  TDS: Latch: LA_251920465_DispenseHeightToStrip_ECRO; CEID15651.10  115927 non-null  float64
#  33  TDS: Latch: LA_251920580_DispenserPressure_ECRO; CEID15651.9       115927 non-null  int64
#  34  TDS: Latch: LA_269353054_DevicePositionXOnLFAtP1; CEID15651.4      115927 non-null  int64
#  35  TDS: Latch: LA_269353055_DevicePositionYOnLFAtP1; CEID15651.5      115927 non-null  int64
#  36  TDS: Latch: LA_269353092_DispenseCurrentBondPosition; CEID15651.6  115927 non-null  int64
#  37  TDS: Latch: LA_269353094_DispenseProcessAvePress; CEID15651.7      115927 non-null  int64
#  38  TDS: Latch: LA_269353095_DispenseProcessAveZHeight; CEID15651.8    115927 non-null  float64
#  39  TDS: Sig: DispenseProcess_AvePress (post Step)                     115927 non-null  float64
#  40  TDS: Sig: DispenseProcess_AveZHeight (post Step)                   115927 non-null  float64
#  41  TDS: Sig: Framing - Dispense Process Done (post Step)              115927 non-null  float64
#  42  TDS: Status                                                        115927 non-null  int64
#  43  TDS: Tool Bin Data Age                                             115927 non-null  int64
#  44  TDS: Tool Bin Polling Latency                                      115927 non-null  int64
#  45  TDS: Trigger: CEID15310; CE_15310_StripArrivedClamp1               115927 non-null  float64
#  46  TDS: Trigger: CEID15318; CE_15318_StripRemovedClamp1               115927 non-null  float64
#  47  TDS: Trigger: CEID15319; CE_15319_StripLeftClamp1                  115927 non-null  float64
#  48  TDS: Trigger: CEID15320; CE_15320_StripArrivedClamp2               115927 non-null  float64
#  49  TDS: Trigger: CEID15328; CE_15328_StripRemovedClamp2               115927 non-null  float64
#  50  TDS: Trigger: CEID15329; CE_15329_StripLeftClamp2                  115927 non-null  float64
#  51  TDS: Trigger: CEID15330; CE_15330_StripArrivedClamp3               115927 non-null  float64
#  52  TDS: Trigger: CEID15331; CE_15331_StripInsertedClamp3              115927 non-null  float64
#  53  TDS: Trigger: CEID15338; CE_15338_StripRemovedClamp3               115927 non-null  float64
#  54  TDS: Trigger: CEID15339; CE_15339_StripLeftClamp3                  115927 non-null  float64
#  55  TDS: Trigger: CEID15651; CE_15651_DispenseProcessDone              115927 non-null  float64
#  56  TDS: Trigger: CEID15652; CE_15652_BondProcessDone                  115927 non-null  float64
#  57  TDS: Trigger: CEID15653; CE_15653_PickProcessDone                  115927 non-null  float64
#  58  TDS: Trigger: CEID3211; CE_3211_EnterExecProcessState              115927 non-null  float64
# dtypes: float64(19), int64(10), object(30)
# memory usage: 52.2+ MB

# %%
df['Run Start Time'] = pd.to_datetime(df['Run Start Time'])

# %%
df['Run Start Time']
# Out:
# 0        2020-03-19 01:02:00
# 1        2020-03-19 01:02:00
# 2        2020-03-19 01:02:00
# 3        2020-03-19 01:02:00
# 4        2020-03-19 01:02:00
#                  ...
# 115922   2020-03-19 05:59:00
# 115923   2020-03-19 05:59:00
# 115924   2020-03-19 05:59:00
# 115925   2020-03-19 05:59:00
# 115926   2020-03-19 05:59:00
# Name: Run Start Time, Length: 115927, dtype: datetime64[ns]

# %%
df['Date_Run_Start_Time'] = df['Run Start Time'].dt.date

# %%
df['Date_Run_Start_Time']
# Out:
# 0         2020-03-19
# 1         2020-03-19
# 2         2020-03-19
# 3         2020-03-19
# 4         2020-03-19
#              ...
# 115922    2020-03-19
# 115923    2020-03-19
# 115924    2020-03-19
# 115925    2020-03-19
# 115926    2020-03-19
# Name: Date_Run_Start_Time, Length: 115927, dtype: object

# %%
df['Time_Run_Start'] = df['Run Start Time'].dt.time

# %%
type(df['Time_Run_Start'])
# Out:
# pandas.core.series.Series

# %%
df[["Time_Run_Start","Date_Run_Start_Time","Run Start Time"]]
# Out:
#        Time_Run_Start Date_Run_Start_Time      Run Start Time
# 0            01:02:00          2020-03-19 2020-03-19 01:02:00
# 1            01:02:00          2020-03-19 2020-03-19 01:02:00
# 2            01:02:00          2020-03-19 2020-03-19 01:02:00
# 3            01:02:00          2020-03-19 2020-03-19 01:02:00
# 4            01:02:00          2020-03-19 2020-03-19 01:02:00
# ...               ...                 ...                 ...
# 115922       05:59:00          2020-03-19 2020-03-19 05:59:00
# 115923       05:59:00          2020-03-19 2020-03-19 05:59:00
# 115924       05:59:00          2020-03-19 2020-03-19 05:59:00
# 115925       05:59:00          2020-03-19 2020-03-19 05:59:00
# 115926       05:59:00          2020-03-19 2020-03-19 05:59:00
#
# [115927 rows x 3 columns]

# %%
df[["Time_Run_Start","Date_Run_Start_Time","Run Start Time"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115927 entries, 0 to 115926
# Data columns (total 3 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Time_Run_Start       115927 non-null  object
#  1   Date_Run_Start_Time  115927 non-null  object
#  2   Run Start Time       115927 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 2.7+ MB

# %%
df["Time"].head(50)
# Out:
# 0     02:57.0
# 1     02:57.1
# 2     02:57.2
# 3     02:57.3
# 4     02:57.5
# 5     02:58.6
# 6     02:58.7
# 7     02:58.8
# 8     02:58.9
# 9     02:59.0
# 10    02:58.1
# 11    02:58.2
# 12    02:58.3
# 13    02:58.4
# 14    02:59.5
# 15    02:59.7
# 16    02:59.8
# 17    02:59.9
# 18    03:00.0
# 19    02:59.1
# 20    02:59.2
# 21    02:59.3
# 22    02:59.4
# 23    02:59.5
# 24    03:00.6
# 25    03:00.7
# 26    03:00.9
# 27    03:01.0
# 28    03:00.1
# 29    03:00.2
# 30    03:00.3
# 31    03:00.4
# 32    03:00.5
# 33    03:01.6
# 34    07:08.0
# 35    07:08.1
# 36    07:08.2
# 37    07:09.3
# 38    07:09.5
# 39    07:09.6
# 40    07:09.7
# 41    07:09.8
# 42    07:09.9
# 43    07:10.0
# 44    07:09.1
# 45    07:09.2
# 46    07:09.3
# 47    07:10.4
# 48    07:10.5
# 49    07:10.7
# Name: Time, dtype: object

# %% [markdown]
# # Selected the TDS
